# %% [markdown]
# # Imports

# %%
# %matplotlib qt
import matplotlib.pyplot as plt
import numpy as np
from snmf import SNMF
import EDXS_model
import h5py
# hyperspy is the commonly used library to handle spectrum images in the electron microscopy community
import hyperspy.api as hs
import utils as u

# %% [markdown]
# # Load the data

# %%
# filename="Data/71GPa_subsolidus"
filename = "Data/aspim037_N100_2ptcls_brstlg"

S=hs.load(filename+".hspy")
X=S.data

# This part of the spectrum image contains only pure spectra from phase 0
# This kind of area is often available in experimental datasets
X_part=S.inav[60:,:].data

# %% [markdown]
# # Performance assessment functions
#
# These functions are used to compare the endmembers determined by SNMF and the ground truth

# %%
# This function will find the best matching endmember for each true spectrum. This is useful since the A and P matrice are initialized at random. 

# This function works but can probably greatly improved
def find_min_angle (list_true_vectors,list_algo_vectors) :
    # This function calculates all the possible angles between endmembers and true spectra
    # For each true spectrum a best matching endmember is found
    # The function returns the angles of the corresponding pairs
    copy_algo_vectors=list_algo_vectors.copy()
    size=list_algo_vectors[0].shape
    ordered_angles=[]
    for i in range(len(list_true_vectors)) :
        list_angles=[]
        for j in range(len(list_algo_vectors)) :
            list_angles.append(u.Functions.spectral_angle(list_true_vectors[i],list_algo_vectors[j]))
        ind_min=np.argmin(np.array(list_angles))
        list_algo_vectors[ind_min]=1e28*np.ones(size)
        ordered_angles.append(u.Functions.spectral_angle(list_true_vectors[i],copy_algo_vectors[ind_min]))
    return ordered_angles

# This function works but can probably greatly improved
def find_min_MSE (list_true_maps,list_algo_maps) :
    # This function calculates all the possible MSE between abundances and true maps
    # For each true map a best matching abundance is found
    # The function returns the MSE of the corresponding pairs
    copy_algo_maps=list_algo_maps.copy()
    size=list_algo_maps[0].shape
    ordered_maps=[]
    for i in range(len(list_true_maps)) :
        list_maps=[]
        for j in range(len(list_algo_maps)) :
            list_maps.append(u.Functions.MSE_map(list_true_maps[i],list_algo_maps[j]))
        ind_min=np.argmin(np.array(list_maps))
        list_algo_maps[ind_min]=1e28*np.ones(size)
        ordered_maps.append(u.Functions.MSE_map(list_true_maps[i],copy_algo_maps[ind_min]))
    return ordered_maps

# This function gives the residuals between the model determined by snmf and the data that were fitted
def residuals (data,model) :
    X_sum=data.sum(axis=0).sum(axis=0)
    model_sum=model.get_phase_map(0).sum()*model.get_phase_spectrum(0)+model.get_phase_map(1).sum()*model.get_phase_spectrum(1)+model.get_phase_map(2).sum()*model.get_phase_spectrum(2)
    return X_sum-model_sum

# %% [markdown]
# # Parameters

# %%
# True bremsstrahlung parameters
brstlg_pars = {"c0" : 4.8935e-05,"c1" : 1464.19810, "c2" : 0.04216872, "b0" : 0.15910789, "b1" : -0.00773158, "b2" : 8.7417e-04}
# brstlg_pars = {
#                 "c0"  :  8.0192e-08,
#                 "c1"  :  380.523471	,
#                 "c2"  :  2.7332e-11,
#                 "b0"  :  0.09002422,
#                 "b1"  :  -0.0162849,
#                 "b2"  :  0.00193291
#                 }


# SNMF parameters
tol = 1e-4
max_iter = 50000
b_tol = 1e-1
mu_sparse = 0.0
eps_sparse = 1.0
phases = 3
em = EDXS_model.EDXS_Model("Data/simple_xrays_threshold.json",brstlg_pars = brstlg_pars,e_offset=S.axes_manager[2].offset,e_scale=S.axes_manager[2].scale,e_size=S.axes_manager[2].size)
em.generate_g_matr([8,13,14,12,26,29,31,72,71,62,60,92,20],brstlg = False)
# em.generate_g_matr([12,13,14,20,26,29,31,34,40,60,62,71,92],brstlg = True)

# Loading of ground truth
true_spectra=[]
true_maps=[]
true_spectra.append(np.genfromtxt(filename+"spectrum_p0"))
true_spectra.append(np.genfromtxt(filename+"spectrum_p1"))
true_spectra.append(np.genfromtxt(filename+"spectrum_p2"))
true_maps.append(np.load(filename+"map_p0.npy"))
true_maps.append(np.load(filename+"map_p1.npy"))
true_maps.append(np.load(filename+"map_p2.npy"))

# # If mu_sparse !=0 a good initialization of the first phase is required, it can be done using the spectrum below
init_matrix=np.average(X_part,axis=(0,1))

# %% [markdown]
# # SNMF

# %%
# Creation of an SNMF object with the parameters above
mdl = SNMF(max_iter = max_iter, tol = tol, b_tol = b_tol, mu_sparse=mu_sparse, eps_sparse = eps_sparse, num_phases=phases,edxs_model=em, brstlg_pars = brstlg_pars, init_spectrum = init_matrix)

# %%
mdl.fit(X,eval_print=True)
# Out:
# 04 of maximal 50000 function value decreased by: 0.00018596858717501163 taking: 4.854860544204712 secondsafter b 0.0
# Finished iteration 12105 of maximal 50000 function value decreased by: 0.00018596858717501163 taking: 3.6488592624664307 secondsafter b 2.3283064365386963e-10
# Finished iteration 12106 of maximal 50000 function value decreased by: 0.00018596858717501163 taking: 3.6249537467956543 secondsafter b 0.0
# Finished iteration 12107 of maximal 50000 function value decreased by: 0.00018596858717501163 taking: 3.521897315979004 secondsafter b 0.0
# Finished iteration 12108 of maximal 50000 function value decreased by: 0.00018596858717501163 taking: 3.8777036666870117 secondsafter b 0.0
# Finished iteration 12109 of maximal 50000 function value decreased by: 0.00018596858717501163 taking: 3.507946491241455 secondsafter b 0.0
# Finished iteration 12110 of maximal 50000 function value decreased by: 0.00018596858717501163 taking: 3.500734329223633 secondsafter b 0.0
# Finished iteration 12111 of maximal 50000 function value decreased by: 0.0001836747396737337 taking: 3.80222749710083 secondsafter b 0.0
# Finished iteration 12112 of maximal 50000 function value decreased by: 0.0001836747396737337 taking: 3.6188693046569824 secondsafter b 4.656612873077393e-10
# Finished iteration 12113 of maximal 50000 function value decreased by: 0.0001836747396737337 taking: 3.9588420391082764 secondsafter b 0.0
# Finished iteration 12114 of maximal 50000 function value decreased by: 0.0001836747396737337 taking: 7.020709037780762 secondsafter b 0.0
# Finished iteration 12115 of maximal 50000 function value decreased by: 0.0001836747396737337 taking: 3.6199448108673096 secondsafter b 2.3283064365386963e-10
# Finished iteration 12116 of maximal 50000 function value decreased by: 0.0001836747396737337 taking: 3.63276743888855 secondsafter b 0.0
# Finished iteration 12117 of maximal 50000 function value decreased by: 0.0001836747396737337 taking: 8.363713026046753 secondsafter b 0.0
# Finished iteration 12118 of maximal 50000 function value decreased by: 0.0001836747396737337 taking: 3.6388485431671143 secondsafter b 0.0
# Finished iteration 12119 of maximal 50000 function value decreased by: 0.0001836747396737337 taking: 3.5605762004852295 secondsafter b 0.0
# Finished iteration 12120 of maximal 50000 function value decreased by: 0.0001836747396737337 taking: 3.5621159076690674 secondsafter b 6.984919309616089e-10
# Finished iteration 12121 of maximal 50000 function value decreased by: 0.00018021301366388798 taking: 3.876917839050293 secondsafter b 0.0
# Finished iteration 12122 of maximal 50000 function value decreased by: 0.00018021301366388798 taking: 8.64660930633545 secondsafter b 0.0
# Finished iteration 12123 of maximal 50000 function value decreased by: 0.00018021301366388798 taking: 3.469896078109741 secondsafter b 2.3283064365386963e-10
# Finished iteration 12124 of maximal 50000 function value decreased by: 0.00018021301366388798 taking: 3.431973457336426 secondsafter b 0.0
# Finished iteration 12125 of maximal 50000 function value decreased by: 0.00018021301366388798 taking: 3.730736255645752 secondsafter b 0.0
# Finished iteration 12126 of maximal 50000 function value decreased by: 0.00018021301366388798 taking: 8.92420482635498 secondsafter b 0.0
# Finished iteration 12127 of maximal 50000 function value decreased by: 0.00018021301366388798 taking: 3.5880377292633057 secondsafter b 0.0
# Finished iteration 12128 of maximal 50000 function value decreased by: 0.00018021301366388798 taking: 3.5571703910827637 secondsafter b 0.0
# Finished iteration 12129 of maximal 50000 function value decreased by: 0.00018021301366388798 taking: 3.5751731395721436 secondsafter b 2.3283064365386963e-10
# Finished iteration 12130 of maximal 50000 function value decreased by: 0.00018021301366388798 taking: 3.5305941104888916 secondsafter b 0.0
# Finished iteration 12131 of maximal 50000 function value decreased by: 0.00017567165195941925 taking: 4.098834753036499 secondsafter b 0.0
# Finished iteration 12132 of maximal 50000 function value decreased by: 0.00017567165195941925 taking: 3.571293592453003 secondsafter b 0.0
# Finished iteration 12133 of maximal 50000 function value decreased by: 0.00017567165195941925 taking: 5.128770351409912 secondsafter b 0.0
# Finished iteration 12134 of maximal 50000 function value decreased by: 0.00017567165195941925 taking: 3.652381420135498 secondsafter b 0.0
# Finished iteration 12135 of maximal 50000 function value decreased by: 0.00017567165195941925 taking: 3.9268648624420166 secondsafter b 2.3283064365386963e-10
# Finished iteration 12136 of maximal 50000 function value decreased by: 0.00017567165195941925 taking: 3.5668785572052 secondsafter b 0.0
# Finished iteration 12137 of maximal 50000 function value decreased by: 0.00017567165195941925 taking: 3.9078590869903564 secondsafter b 0.0
# Finished iteration 12138 of maximal 50000 function value decreased by: 0.00017567165195941925 taking: 3.5281686782836914 secondsafter b 0.0
# Finished iteration 12139 of maximal 50000 function value decreased by: 0.00017567165195941925 taking: 3.9238812923431396 secondsafter b 0.0
# Finished iteration 12140 of maximal 50000 function value decreased by: 0.00017567165195941925 taking: 3.6965043544769287 secondsafter b 4.656612873077393e-10
# Finished iteration 12141 of maximal 50000 function value decreased by: 0.00017014658078551292 taking: 3.917905330657959 secondsafter b 0.0
# Finished iteration 12142 of maximal 50000 function value decreased by: 0.00017014658078551292 taking: 3.600778579711914 secondsafter b 4.656612873077393e-10
# Finished iteration 12143 of maximal 50000 function value decreased by: 0.00017014658078551292 taking: 3.5360000133514404 secondsafter b 0.0
# Finished iteration 12144 of maximal 50000 function value decreased by: 0.00017014658078551292 taking: 3.888108015060425 secondsafter b 0.0
# Finished iteration 12145 of maximal 50000 function value decreased by: 0.00017014658078551292 taking: 8.457651138305664 secondsafter b 0.0
# Finished iteration 12146 of maximal 50000 function value decreased by: 0.00017014658078551292 taking: 5.621644973754883 secondsafter b 0.0
# Finished iteration 12147 of maximal 50000 function value decreased by: 0.00017014658078551292 taking: 4.396731376647949 secondsafter b 0.0
# Finished iteration 12148 of maximal 50000 function value decreased by: 0.00017014658078551292 taking: 3.7867064476013184 secondsafter b 4.656612873077393e-10
# Finished iteration 12149 of maximal 50000 function value decreased by: 0.00017014658078551292 taking: 3.5289528369903564 secondsafter b 2.3283064365386963e-10
# Finished iteration 12150 of maximal 50000 function value decreased by: 0.00017014658078551292 taking: 3.600844144821167 secondsafter b 0.0
# Finished iteration 12151 of maximal 50000 function value decreased by: 0.00016380543820559978 taking: 5.494736909866333 secondsafter b 2.3283064365386963e-10
# Finished iteration 12152 of maximal 50000 function value decreased by: 0.00016380543820559978 taking: 3.537889003753662 secondsafter b 0.0
# Finished iteration 12153 of maximal 50000 function value decreased by: 0.00016380543820559978 taking: 6.510833740234375 secondsafter b 0.0
# Finished iteration 12154 of maximal 50000 function value decreased by: 0.00016380543820559978 taking: 4.244237899780273 secondsafter b 0.0
# Finished iteration 12155 of maximal 50000 function value decreased by: 0.00016380543820559978 taking: 3.6645102500915527 secondsafter b 2.3283064365386963e-10
# Finished iteration 12156 of maximal 50000 function value decreased by: 0.00016380543820559978 taking: 3.5717508792877197 secondsafter b 2.3283064365386963e-10
# Finished iteration 12157 of maximal 50000 function value decreased by: 0.00016380543820559978 taking: 3.850255012512207 secondsafter b 9.313225746154785e-10
# Finished iteration 12158 of maximal 50000 function value decreased by: 0.00016380543820559978 taking: 3.716417074203491 secondsafter b 2.3283064365386963e-10
# Finished iteration 12159 of maximal 50000 function value decreased by: 0.00016380543820559978 taking: 3.68686842918396 secondsafter b 4.656612873077393e-10
# Finished iteration 12160 of maximal 50000 function value decreased by: 0.00016380543820559978 taking: 3.660860300064087 secondsafter b 0.0
# Finished iteration 12161 of maximal 50000 function value decreased by: 0.000156833091750741 taking: 3.922900438308716 secondsafter b 0.0
# Finished iteration 12162 of maximal 50000 function value decreased by: 0.000156833091750741 taking: 4.2687671184539795 secondsafter b 0.0
# Finished iteration 12163 of maximal 50000 function value decreased by: 0.000156833091750741 taking: 5.722091197967529 secondsafter b 0.0
# Finished iteration 12164 of maximal 50000 function value decreased by: 0.000156833091750741 taking: 5.649782657623291 secondsafter b 2.3283064365386963e-10
# Finished iteration 12165 of maximal 50000 function value decreased by: 0.000156833091750741 taking: 3.587886095046997 secondsafter b 2.3283064365386963e-10
# Finished iteration 12166 of maximal 50000 function value decreased by: 0.000156833091750741 taking: 3.957571029663086 secondsafter b 0.0
# Finished iteration 12167 of maximal 50000 function value decreased by: 0.000156833091750741 taking: 3.6516289710998535 secondsafter b 1.3969838619232178e-09
# Finished iteration 12168 of maximal 50000 function value decreased by: 0.000156833091750741 taking: 3.6891469955444336 secondsafter b 2.3283064365386963e-10
# Finished iteration 12169 of maximal 50000 function value decreased by: 0.000156833091750741 taking: 3.5004985332489014 secondsafter b 0.0
# Finished iteration 12170 of maximal 50000 function value decreased by: 0.000156833091750741 taking: 3.505056619644165 secondsafter b 1.3969838619232178e-09
# Finished iteration 12171 of maximal 50000 function value decreased by: 0.00014941650442779064 taking: 4.16290283203125 secondsafter b 2.3283064365386963e-10
# Finished iteration 12172 of maximal 50000 function value decreased by: 0.00014941650442779064 taking: 3.5559308528900146 secondsafter b 4.656612873077393e-10
# Finished iteration 12173 of maximal 50000 function value decreased by: 0.00014941650442779064 taking: 3.508711576461792 secondsafter b 1.3969838619232178e-09
# Finished iteration 12174 of maximal 50000 function value decreased by: 0.00014941650442779064 taking: 3.5184671878814697 secondsafter b 2.3283064365386963e-10
# Finished iteration 12175 of maximal 50000 function value decreased by: 0.00014941650442779064 taking: 5.257061243057251 secondsafter b 1.3969838619232178e-09
# Finished iteration 12176 of maximal 50000 function value decreased by: 0.00014941650442779064 taking: 3.5518383979797363 secondsafter b 3.259629011154175e-09
# Finished iteration 12177 of maximal 50000 function value decreased by: 0.00014941650442779064 taking: 3.5488972663879395 secondsafter b 9.313225746154785e-10
# Finished iteration 12178 of maximal 50000 function value decreased by: 0.00014941650442779064 taking: 3.60288143157959 secondsafter b 2.3283064365386963e-10
# Finished iteration 12179 of maximal 50000 function value decreased by: 0.00014941650442779064 taking: 5.426738739013672 secondsafter b 1.1641532182693481e-09
# Finished iteration 12180 of maximal 50000 function value decreased by: 0.00014941650442779064 taking: 3.926835298538208 secondsafter b 2.3283064365386963e-10
# Finished iteration 12181 of maximal 50000 function value decreased by: 0.00014176126569509506 taking: 9.342740297317505 secondsafter b 0.0
# Finished iteration 12182 of maximal 50000 function value decreased by: 0.00014176126569509506 taking: 16.168774843215942 secondsafter b 0.0
# Finished iteration 12183 of maximal 50000 function value decreased by: 0.00014176126569509506 taking: 3.4674816131591797 secondsafter b 0.0
# Finished iteration 12184 of maximal 50000 function value decreased by: 0.00014176126569509506 taking: 3.9868152141571045 secondsafter b 0.0
# Finished iteration 12185 of maximal 50000 function value decreased by: 0.00014176126569509506 taking: 3.70393705368042 secondsafter b 2.3283064365386963e-10
# Finished iteration 12186 of maximal 50000 function value decreased by: 0.00014176126569509506 taking: 3.6498446464538574 secondsafter b 0.0
# Finished iteration 12187 of maximal 50000 function value decreased by: 0.00014176126569509506 taking: 7.378979921340942 secondsafter b 0.0
# Finished iteration 12188 of maximal 50000 function value decreased by: 0.00014176126569509506 taking: 3.581615686416626 secondsafter b 0.0
# Finished iteration 12189 of maximal 50000 function value decreased by: 0.00014176126569509506 taking: 3.9147279262542725 secondsafter b 0.0
# Finished iteration 12190 of maximal 50000 function value decreased by: 0.00014176126569509506 taking: 3.5819804668426514 secondsafter b 0.0
# Finished iteration 12191 of maximal 50000 function value decreased by: 0.00013404758647084236 taking: 4.0346903800964355 secondsafter b 0.0
# Finished iteration 12192 of maximal 50000 function value decreased by: 0.00013404758647084236 taking: 3.5888240337371826 secondsafter b 0.0
# Finished iteration 12193 of maximal 50000 function value decreased by: 0.00013404758647084236 taking: 3.8575427532196045 secondsafter b 0.0
# Finished iteration 12194 of maximal 50000 function value decreased by: 0.00013404758647084236 taking: 3.632272958755493 secondsafter b 0.0
# Finished iteration 12195 of maximal 50000 function value decreased by: 0.00013404758647084236 taking: 3.5649449825286865 secondsafter b 0.0
# Finished iteration 12196 of maximal 50000 function value decreased by: 0.00013404758647084236 taking: 3.536795139312744 secondsafter b 0.0
# Finished iteration 12197 of maximal 50000 function value decreased by: 0.00013404758647084236 taking: 3.5745797157287598 secondsafter b 0.0
# Finished iteration 12198 of maximal 50000 function value decreased by: 0.00013404758647084236 taking: 3.8044681549072266 secondsafter b 0.0
# Finished iteration 12199 of maximal 50000 function value decreased by: 0.00013404758647084236 taking: 3.5925817489624023 secondsafter b 0.0
# Finished iteration 12200 of maximal 50000 function value decreased by: 0.00013404758647084236 taking: 4.730756521224976 secondsafter b 0.0
# Finished iteration 12201 of maximal 50000 function value decreased by: 0.00012645544484257698 taking: 3.7834067344665527 secondsafter b 0.0
# Finished iteration 12202 of maximal 50000 function value decreased by: 0.00012645544484257698 taking: 7.623106002807617 secondsafter b 0.0
# Finished iteration 12203 of maximal 50000 function value decreased by: 0.00012645544484257698 taking: 3.558931589126587 secondsafter b 0.0
# Finished iteration 12204 of maximal 50000 function value decreased by: 0.00012645544484257698 taking: 3.620439291000366 secondsafter b 0.0
# Finished iteration 12205 of maximal 50000 function value decreased by: 0.00012645544484257698 taking: 3.5062966346740723 secondsafter b 4.656612873077393e-10
# Finished iteration 12206 of maximal 50000 function value decreased by: 0.00012645544484257698 taking: 3.9068305492401123 secondsafter b 0.0
# Finished iteration 12207 of maximal 50000 function value decreased by: 0.00012645544484257698 taking: 4.551832675933838 secondsafter b 2.3283064365386963e-10
# Finished iteration 12208 of maximal 50000 function value decreased by: 0.00012645544484257698 taking: 3.6102821826934814 secondsafter b 2.3283064365386963e-10
# Finished iteration 12209 of maximal 50000 function value decreased by: 0.00012645544484257698 taking: 5.173319101333618 secondsafter b 0.0
# Finished iteration 12210 of maximal 50000 function value decreased by: 0.00012645544484257698 taking: 3.6739156246185303 secondsafter b 0.0
# Finished iteration 12211 of maximal 50000 function value decreased by: 0.00011913874186575413 taking: 4.282151222229004 secondsafter b 0.0
# Finished iteration 12212 of maximal 50000 function value decreased by: 0.00011913874186575413 taking: 3.6659770011901855 secondsafter b 0.0
# Finished iteration 12213 of maximal 50000 function value decreased by: 0.00011913874186575413 taking: 3.599804639816284 secondsafter b 0.0
# Finished iteration 12214 of maximal 50000 function value decreased by: 0.00011913874186575413 taking: 3.6689023971557617 secondsafter b 0.0
# Finished iteration 12215 of maximal 50000 function value decreased by: 0.00011913874186575413 taking: 5.882680177688599 secondsafter b 0.0
# Finished iteration 12216 of maximal 50000 function value decreased by: 0.00011913874186575413 taking: 3.5229604244232178 secondsafter b 2.3283064365386963e-10
# Finished iteration 12217 of maximal 50000 function value decreased by: 0.00011913874186575413 taking: 3.480854034423828 secondsafter b 0.0
# Finished iteration 12218 of maximal 50000 function value decreased by: 0.00011913874186575413 taking: 3.547271251678467 secondsafter b 0.0
# Finished iteration 12219 of maximal 50000 function value decreased by: 0.00011913874186575413 taking: 5.876654386520386 secondsafter b 0.0
# Finished iteration 12220 of maximal 50000 function value decreased by: 0.00011913874186575413 taking: 4.960458517074585 secondsafter b 0.0
# Finished iteration 12221 of maximal 50000 function value decreased by: 0.00011219666339457035 taking: 5.790978670120239 secondsafter b 0.0
# Finished iteration 12222 of maximal 50000 function value decreased by: 0.00011219666339457035 taking: 3.5267276763916016 secondsafter b 0.0
# Finished iteration 12223 of maximal 50000 function value decreased by: 0.00011219666339457035 taking: 3.5868277549743652 secondsafter b 0.0
# Finished iteration 12224 of maximal 50000 function value decreased by: 0.00011219666339457035 taking: 3.923868179321289 secondsafter b 0.0
# Finished iteration 12225 of maximal 50000 function value decreased by: 0.00011219666339457035 taking: 3.606194257736206 secondsafter b 0.0
# Finished iteration 12226 of maximal 50000 function value decreased by: 0.00011219666339457035 taking: 3.5050554275512695 secondsafter b 0.0
# Finished iteration 12227 of maximal 50000 function value decreased by: 0.00011219666339457035 taking: 4.1563637256622314 secondsafter b 0.0
# Finished iteration 12228 of maximal 50000 function value decreased by: 0.00011219666339457035 taking: 3.7168076038360596 secondsafter b 2.3283064365386963e-10
# Finished iteration 12229 of maximal 50000 function value decreased by: 0.00011219666339457035 taking: 3.8988723754882812 secondsafter b 0.0
# Finished iteration 12230 of maximal 50000 function value decreased by: 0.00011219666339457035 taking: 3.612844467163086 secondsafter b 2.3283064365386963e-10
# Finished iteration 12231 of maximal 50000 function value decreased by: 0.00010573561303317547 taking: 4.8378520011901855 secondsafter b 6.984919309616089e-10
# Finished iteration 12232 of maximal 50000 function value decreased by: 0.00010573561303317547 taking: 3.6478962898254395 secondsafter b 2.3283064365386963e-10
# Finished iteration 12233 of maximal 50000 function value decreased by: 0.00010573561303317547 taking: 3.8683784008026123 secondsafter b 0.0
# Finished iteration 12234 of maximal 50000 function value decreased by: 0.00010573561303317547 taking: 6.320122480392456 secondsafter b 2.3283064365386963e-10
# Finished iteration 12235 of maximal 50000 function value decreased by: 0.00010573561303317547 taking: 4.831221342086792 secondsafter b 0.0
# Finished iteration 12236 of maximal 50000 function value decreased by: 0.00010573561303317547 taking: 3.986466407775879 secondsafter b 2.3283064365386963e-10
# Finished iteration 12237 of maximal 50000 function value decreased by: 0.00010573561303317547 taking: 3.521960496902466 secondsafter b 0.0
# Finished iteration 12238 of maximal 50000 function value decreased by: 0.00010573561303317547 taking: 8.11365818977356 secondsafter b 0.0
# Finished iteration 12239 of maximal 50000 function value decreased by: 0.00010573561303317547 taking: 3.555896043777466 secondsafter b 0.0
# Finished iteration 12240 of maximal 50000 function value decreased by: 0.00010573561303317547 taking: 3.6637370586395264 secondsafter b 2.3283064365386963e-10
#
# old function: 1621702.4524222657, new_function: 1621702.452322475
#
# Stopped after 12241 iterations in 733.0 minutes and 54.0 seconds.
# (array([[1.26238926e-001, 9.85532611e-002, 1.90209755e-001],
#         [7.34003139e-003, 9.28260888e-004, 4.41900447e-002],
#         [9.42704241e-002, 1.13634187e-055, 9.55362763e-018],
#         [4.16016324e-002, 2.51541146e-001, 1.33432651e-107],
#         [2.28500703e-126, 3.22237254e-002, 1.78629669e-003],
#         [8.04414948e-162, 2.31807327e-002, 9.49534236e-017],
#         [2.21067730e-184, 3.85488630e-002, 1.67232754e-037],
#         [1.77257302e-003, 9.17391286e-003, 1.06980657e-003],
#         [1.41823646e-044, 1.59135436e-002, 1.18004758e-002],
#         [7.92193520e-033, 1.33293567e-002, 3.86969452e-003],
#         [8.92524200e-242, 3.75380308e-003, 9.14978786e-100],
#         [1.83982412e-239, 5.44308766e-003, 4.22058363e-004],
#         [2.79094083e-233, 4.47310710e-003, 1.14629132e-043],
#         [2.36618184e-091, 4.19418238e-004, 2.31131267e-003],
#         [5.61282760e-004, 6.81384465e-012, 3.19538026e-004],
#         [3.58441366e-004, 7.83818565e-004, 6.11279522e-004],
#         [5.75667773e-005, 1.90847584e-023, 5.21693717e-021],
#         [1.61481729e-004, 2.90417162e-003, 1.49911813e-003],
#         [6.50438443e-004, 5.63572574e-055, 3.58134537e-004],
#         [1.33907527e-078, 2.13355909e-003, 1.04709398e-069],
#         [3.35060802e-004, 1.19999881e-029, 2.08248430e-003],
#         [1.23179600e-011, 9.54773174e-005, 4.52727198e-011],
#         [7.65904646e-014, 1.69606741e-003, 9.44832774e-005],
#         [1.58817656e-003, 2.25883326e-003, 1.16195331e-002],
#         [3.00301921e-003, 3.48335430e-024, 6.68320318e-003],
#         [2.22778719e-003, 7.69751107e-004, 9.45877724e-003],
#         [1.93793873e-003, 4.29974195e-003, 7.86585445e-003],
#         [2.84396573e-033, 2.73334394e-003, 1.85757300e-002],
#         [3.43361528e-063, 7.08126679e-004, 3.21031325e-003],
#         [4.07234840e-033, 4.44575491e-081, 2.89009245e-003],
#         [1.08506211e-013, 1.03856798e-003, 2.89966735e-003],
#         [1.10758878e-120, 6.12400630e-004, 2.36694287e-005],
#         [1.73984818e-129, 4.19821658e-003, 5.46349186e-003],
#         [1.41232468e-177, 4.88549915e-004, 5.25751673e-179],
#         [1.48509800e-004, 3.45564701e-117, 2.16523123e-101],
#         [8.55577179e-165, 3.50244816e-004, 3.34782612e-071],
#         [6.08324902e-213, 1.64333646e-003, 2.42129287e-004],
#         [1.34408369e-243, 3.13246065e-004, 2.08360281e-003],
#         [1.40859993e-317, 2.12249119e-318, 1.01603774e-001],
#         [8.32492036e-246, 3.39840839e-166, 1.02259995e-001]]),
#  array([[8.00724943e-001, 9.99999942e-001, 8.72127666e-001, ...,
#          7.63310078e-001, 7.51678640e-001, 8.87632267e-001],
#         [1.46944727e-001, 1.64029794e-321, 1.19844998e-001, ...,
#          1.46704509e-001, 2.10923444e-001, 6.25199692e-002],
#         [5.23343123e-002, 2.13436359e-321, 8.02609840e-003, ...,
#          8.99838435e-002, 3.74015647e-002, 4.98515665e-002]]))

# %%
filename = "Results/71GPa_subsolidus_mu3.0_eps1.0.hdf5"
# filename = "Results/aspims/aspim_bl_mu0.1_eps1.0_out.hdf5"

with h5py.File(filename, "r") as f:
    # List all groups
    print("Keys: %s" % f.keys())
    a = list(f.keys())[0]
    b = list(f.keys())[1]
    p = list(f.keys())[2]

    # Get the data
    loaded_a = np.array(f[a])
    loaded_b = np.array(f[b])
    loaded_p = np.array(f[p])

h_spec = mdl.g_matr@loaded_p + loaded_b

f_b = "Results/0.3wt%Nd-Sm-Hf-Lu-U-A-X15-71GPa_subsolidus grains_01_Brg spectrum.hdf5"
f_c = "Results/0.3wt%Nd-Sm-Hf-Lu-U-A-X15-71GPa_subsolidus grains_01_CaPv spectrum.hdf5"
f_f = "Results/0.3wt%Nd-Sm-Hf-Lu-U-A-X15-71GPa_subsolidus grains_01_Fp spectrum.hdf5"

with h5py.File(f_b, "r") as f :
    brg = np.array(f["Experiments"]["EDSmap"]["data"])
with h5py.File(f_f, "r") as f :
    fp = np.array(f["Experiments"]["EDSmap"]["data"])
with h5py.File(f_c, "r") as f :
    capv = np.array(f["Experiments"]["EDSmap"]["data"])

x_true = np.linspace(-0.48,-0.48+1047*0.01,num=1047)
true_spectra = [brg,fp,capv]

# %%
trunc_true = x_true > em.x[0]
trunc_res = (em.x < x_true[-1])
res_spec = [h_spec[:,0][trunc_res][:-1],h_spec[:,1][trunc_res][:-1],h_spec[:,2][trunc_res][:-1]]
true_spectra = [brg[trunc_true],fp[trunc_true],capv[trunc_true]]

angles=find_min_angle(true_spectra,res_spec)

print("Angle phase 0 :",angles[0])
print("Angle phase 1 :",angles[1])
print("Angle phase 2 :",angles[2])

# %%
angles=find_min_angle(true_spectra,[h_spec[:,0],h_spec[:,1],h_spec[:,2]])

print("Angle phase 0 :",angles[0])
print("Angle phase 1 :",angles[1])
print("Angle phase 2 :",angles[2])

# %% [markdown]
# # Results

# %%
# Returns the angles between the ground truth and the endmembers found using SNMF
angles=find_min_angle(true_spectra,[mdl.get_phase_spectrum(0),mdl.get_phase_spectrum(1),mdl.get_phase_spectrum(2)])

maps=find_min_MSE(true_maps,[mdl.get_phase_map(0),mdl.get_phase_map(1),mdl.get_phase_map(2)])

print("Angle phase 0 :",angles[0])
print("Angle phase 1 :",angles[1])
print("Angle phase 2 :",angles[2])
print("MSE phase 0 :",maps[0])
print("MSE phase 1 :",maps[1])
print("MSE phase 2 :",maps[2])

# RITM0165818
# Out:
# Angle phase 0 : 8.80590593387548
# Angle phase 1 : 9.237285139093306
# Angle phase 2 : 7.154722215999662
# MSE phase 0 : 174.40770434600745
# MSE phase 1 : 101.81221325408632
# MSE phase 2 : 47.92611403616286

# %% [markdown]
# ### Visualisation of the results

# %%
# switch correspond to the index of the SNMF endmember
# true correspond to the index of the true spectrum
# The 2 should be changed independantly until a match is found
switch = 1
true= 1

plt.rcParams.update({'font.size': 22})
fig1 = plt.figure(figsize=(20, 12))
plt.subplot(121)
plt.plot(em.x,133*true_spectra[true]/np.sum(true_spectra[true]),'bo',label='truth',linewidth=4)
plt.plot(em.x, mdl.get_phase_spectrum(switch),'r-',label='reconstructed',markersize=3.5)
plt.legend(loc='best')
plt.xlim(0, 10)
plt.ylabel("Intensity")

plt.subplot(122)
plt.imshow(mdl.get_phase_map(switch), cmap="viridis")
plt.grid(b=30)
plt.title(f"Activations of first spectrum")
plt.colorbar()
plt.clim(0, 1)

fig1.tight_layout()

# %%
# switch correspond to the index of the SNMF endmember
# true correspond to the index of the true spectrum
# The 2 should be changed independantly until a match is found
switch = 1
true=1

plt.rcParams.update({'font.size': 22})
fig1 = plt.figure(figsize=(20, 12))
plt.subplot(121)
plt.plot(em.x,true_spectra[true]/np.max(true_spectra[true]),'bo',label='truth',linewidth=4)
plt.plot(em.x, h_spec[:,switch]/np.max(h_spec[:,switch]),'r-',label='reconstructed',markersize=3.5)
plt.legend(loc='best')
plt.xlim(0, 10)
plt.ylabel("Intensity")

plt.subplot(122)
plt.imshow(loaded_a[switch].reshape(80,80), cmap="viridis")
plt.grid(b=30)
plt.title(f"Activations of first spectrum")
plt.colorbar()
plt.clim(0, 1)

fig1.tight_layout()

# %%
# switch correspond to the index of the SNMF endmember
# true correspond to the index of the true spectrum
# The 2 should be changed independantly until a match is found
switch = 1
true=2

plt.rcParams.update({'font.size': 22})
fig1 = plt.figure(figsize=(20, 12))
plt.subplot(121)
plt.plot(x_true[trunc_true],50000*true_spectra[true]/np.sum(true_spectra[true]),'bo',label='truth',linewidth=4)
plt.plot(em.x,h_spec[:,switch],'r-',label='reconstructed',markersize=3.5)
plt.legend(loc='best')
plt.xlim(0, 10)
plt.ylabel("Intensity")

plt.subplot(122)
plt.imshow(loaded_a[switch].reshape(201,201), cmap="viridis")
plt.grid(b=30)
plt.title(f"Activations of first spectrum")
plt.colorbar()
plt.clim(0, 1)

fig1.tight_layout()

# %% [markdown]
# # Cross validation

# %% [markdown]
# # En chantier

# %%
init_p_matr = np.random.rand(dl.g_matr.shape[1],dl.p_)
init_p_matr[:,0] = (np.linalg.inv(dl.g_matr.T@dl.g_matr)@dl.g_matr.T@(true_spectra[0]-1.9*Distributions.simplified_brstlg(Gaussians().x,b0,b1,b2,c0))).clip(min=1e-5)
init_p_matr[:,1] = (np.linalg.inv(dl.g_matr.T@dl.g_matr)@dl.g_matr.T@(true_spectra[1]-2.0 *Distributions.simplified_brstlg(Gaussians().x,b0,b1,b2,c0))).clip(min=1e-5)
init_p_matr[:,2] = (np.linalg.inv(dl.g_matr.T@dl.g_matr)@dl.g_matr.T@(true_spectra[2]-1.7*Distributions.simplified_brstlg(Gaussians().x,b0,b1,b2,c0))).clip(min=1e-5)

init_a_matr = np.random.rand(dl.p_, X.shape[0]*X.shape[1])
init_a_matr[0,:]= true_maps[0].reshape(6400)
init_a_matr[1,:]= true_maps[1].reshape(6400)
init_a_matr[2,:]= true_maps[2].reshape(6400)
